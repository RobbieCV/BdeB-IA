# %% [markdown]
# <a href="https://colab.research.google.com/github/RobbieCV/BdeB-IA/blob/main/Pratique_Roberto_Castro_Vexler_2020_10_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Pratique
#Roberto Castro Vexler
#2020-10-22

# %%
## -- Numpy et Pandas ( october 20/10/2020)

# %%
## --- pratique 1:
## construire un vecteur avec [3,4,5,6]
## assigner resultat a la variable vector
## indice : np.array([3,4,5,6])
import numpy as np

vector =np.array([3,4,5,9])

print(vector)
# Out:
# [3 4 5 6]

# %%
## --- pratique 2:
## construire une matrice  depuis la liste de listes [[2,5,15],[20,50,50],[34,99,45]]
## Afficher les resultats
## assigner le resultat a la variable matrix 
matrice = np.array([[2,5,15],[20,50,50],[34,99,45]])
matrice
# Out:
# array([[ 2,  5, 15],
#        [20, 50, 50],
#        [34, 99, 45]])

# %%
## --- pratique 3:
## Donner la taille du tableau [1,2,3,4]suivant puis changer sa taille
## Afficher les resultats
## indication : shape, reshape
tab = np.array([1,2,3,4])
print(tab.shape)
#reshape
tab.reshape(2,2)
# Out:
# (4,)
# array([[1, 2],
#        [3, 4]])

# %%
## --- pratique 4:
## Donner la taille de la matrice [[5,10,15], [20,25,30], [40,45,50]] suivant puis changer sa taille 
## Afficher les resultats
## indication : shape, reshape
matrice = np.array([[5,10,15], [20,25,30], [40,45,50]])
print(matrice.shape)
#reshape
matrice.reshape(1,9)
# Out:
# (3, 3)
# array([[ 5, 10, 15, 20, 25, 30, 40, 45, 50]])

# %%
## --- pratique 5:
## Executer le code suivant ( en specifiant le path du fichier)
import numpy as np
fichier = np.genfromtxt("data_numpy.csv", delimiter=",")
## Utiliser les fonctions type() et print() pour afficher le type de fichier 
print(type(fichier))
#show fichier results
print(fichier)
# Out:
# <class 'numpy.ndarray'>
# [[      nan       nan       nan       nan]
#  [1.986e+03       nan       nan 0.000e+00]
#  [1.986e+03       nan       nan 5.000e-01]
#  ...
#  [1.986e+03       nan       nan 2.540e+00]
#  [1.987e+03       nan       nan 0.000e+00]
#  [1.986e+03       nan       nan 5.150e+00]]

# %%
## --- pratique 6:
## creer un vecteur random ayant 4 valeurs
## creer une matrice random de taille (2X2)
np.random.seed(100)
arr = np.random.randint(0,100,4)
arr.reshape(2,2)
# Out:
# array([[ 8, 24],
#        [67, 87]])

# %%
## --- pratique 7:
# creer un vecteur depuis la liste[1, 2, 3, 4] et afficher son type
##solution
import numpy as np
numbers=np.array([1, 2, 3, 4])
print(numbers)
print(numbers.dtype)
# Out:
# [1 2 3 4]
# int32

# %%
## --- pratique 8
## Afficher toutes les lignes des 2 premières colonnes de data_numpy à la variable first_two_columns.
# Afficher les 10 premières lignes de la première colonne de data_numpy à la variable first_ten_years.
# Afficher les 10 premières lignes de toutes les colonnes de data_numpy à la variable first_ten_rows.
# Afficher les 20 premières lignes des colonnes d'indice 1 et 2 de data_numpy à la variable first_twenty_regions.
display(fichier)
first_two_columns = fichier[:,0:2]
display(first_two_columns)
first_ten_rows = fichier[0:10,0]
display(first_ten_rows)
first_ten_rows = fichier[0:10,:]
display(first_ten_rows)
first_twenty_regions = fichier[0:20,1:2]
display(first_twenty_regions)
# Out:
# array([[      nan,       nan,       nan,       nan],
#        [1.986e+03,       nan,       nan, 0.000e+00],
#        [1.986e+03,       nan,       nan, 5.000e-01],
#        ...,
#        [1.986e+03,       nan,       nan, 2.540e+00],
#        [1.987e+03,       nan,       nan, 0.000e+00],
#        [1.986e+03,       nan,       nan, 5.150e+00]])
# array([[  nan,   nan],
#        [1986.,   nan],
#        [1986.,   nan],
#        ...,
#        [1986.,   nan],
#        [1987.,   nan],
#        [1986.,   nan]])
# array([  nan, 1986., 1986., 1985., 1986., 1987., 1987., 1987., 1985.,
#        1986.])
# array([[      nan,       nan,       nan,       nan],
#        [1.986e+03,       nan,       nan, 0.000e+00],
#        [1.986e+03,       nan,       nan, 5.000e-01],
#        [1.985e+03,       nan,       nan, 1.620e+00],
#        [1.986e+03,       nan,       nan, 4.270e+00],
#        [1.987e+03,       nan,       nan, 1.980e+00],
#        [1.987e+03,       nan,       nan, 0.000e+00],
# ...

# %%
## --- pratique 9
#Importer la librairie pandas.
#Utiliser la fonction pandas.read_csv() pour lire le fichier "food_info.csv" 
#Utiliser les fonctions type() et print() pour afficher le type de food_info

import pandas as pd
df = pd.read_csv("food_info.csv")
display(df)
# Out:
#       NDB_No                                          Shrt_Desc  Water_(g)  \
# 0       1001                                   BUTTER WITH SALT      15.87
# 1       1002                           BUTTER WHIPPED WITH SALT      15.87
# 2       1003                               BUTTER OIL ANHYDROUS       0.24
# 3       1004                                        CHEESE BLUE      42.41
# 4       1005                                       CHEESE BRICK      41.11
# 5       1006                                        CHEESE BRIE      48.42
# 6       1007                                   CHEESE CAMEMBERT      51.80
# 7       1008                                     CHEESE CARAWAY      39.28
# 8       1009                                     CHEESE CHEDDAR      37.10
# 9       1010                                    CHEESE CHESHIRE      37.65
# 10      1011                                       CHEESE COLBY      38.20
# ...

# %%
##--- pratique 10
#Afficher la 1000e ligne du dataframe food_info 
#solution
display(df.loc[999])
# Out:
# NDB_No                                           5236
# Shrt_Desc          TURKEY YOUNG HEN SKN ONLY CKD RSTD
# Water_(g)                                       35.53
# Energ_Kcal                                        482
# Protein_(g)                                     19.03
# Lipid_Tot_(g)                                   44.45
# Ash_(g)                                          0.63
# Carbohydrt_(g)                                      0
# Fiber_TD_(g)                                        0
# Sugar_Tot_(g)                                     NaN
# Calcium_(mg)                                       32
# Iron_(mg)                                        1.82
# Magnesium_(mg)                                     15
# Phosphorus_(mg)                                   133
# Potassium_(mg)                                    155
# Sodium_(mg)                                        44
# Zinc_(mg)                                        2.06
# ...

# %%
##--- pratique 11
#Assigner la colonne "protein_(g)" à la variable protein.
#Assigner la colonne "Cholestrl_(mg)" à la variable cholesterol.
#Afficher les résultats.
#describe(df)
protein = df["Protein_(g)"]
display(protein)
cholesterol = df["Cholestrl_(mg)"]
display(cholesterol)
# Out:
# 0        0.85
# 1        0.85
# 2        0.28
# 3       21.40
# 4       23.24
# 5       20.75
# 6       19.80
# 7       25.18
# 8       24.04
# 9       23.37
# 10      23.76
# 11      11.12
# 12      10.69
# 13      10.34
# 14      10.45
# 15      12.39
# 16       5.93
# 17      24.99
# 18      14.21
# 19      25.60
# 20       9.65
# 21      24.94
# 22      29.81
# 23      20.05
# 24      24.48
# 25      22.17
# 26      21.60
# 27      24.26
# 28      24.58
# 29      23.41
#         ...
# 8588     6.60
# 8589     1.00
# 8590     0.30
# 8591     8.70
# 8592     7.12
# 8593    12.60
# 8594     0.50
# 8595    28.40
# 8596     4.40
# 8597    27.50
# 8598     0.00
# 8599     0.00
# 8600     0.00
# 8601     4.08
# 8602    11.30
# 8603     5.30
# 8604     0.00
# 8605     0.30
# 8606     0.41
# 8607     0.08
# 8608    10.08
# 8609     1.60
# 8610     0.81
# 8611    75.16
# 8612    16.40
# 8613    18.50
# 8614    20.54
# 8615     0.00
# 8616    16.10
# 8617    19.80
# ...

# %%
##--- pratique 12
#Sélectionner les colonnes 'Shrt__Desc', 'Selenium_(mcg)' et 'Thiamin_(mg)' 
#et assigner le dataframe résultant à la variable selenium_thiamin.
#Afficher le résultat.
#describe(df)

selenium_thiamin = df[['Shrt_Desc','Selenium_(mcg)', 'Thiamin_(mg)']]
display(selenium_thiamin)
# Out:
#                                               Shrt_Desc  Selenium_(mcg)  \
# 0                                      BUTTER WITH SALT             1.0
# 1                              BUTTER WHIPPED WITH SALT             1.0
# 2                                  BUTTER OIL ANHYDROUS             0.0
# 3                                           CHEESE BLUE            14.5
# 4                                          CHEESE BRICK            14.5
# 5                                           CHEESE BRIE            14.5
# 6                                      CHEESE CAMEMBERT            14.5
# 7                                        CHEESE CARAWAY            14.5
# 8                                        CHEESE CHEDDAR            28.3
# 9                                       CHEESE CHESHIRE            14.5
# 10                                         CHEESE COLBY            14.5
# 11                  CHEESE COTTAGE CRMD LRG OR SML CURD             9.7
# ...

# %%
## --- pratique 13
# 1) Sélectionner et afficher seulement les colonnes qui utilisent comme unité de mesure les grammes 
#(c'est à dire qui se terminent par "(g)"). Pour cela:
#Utiliser l'attribut columns pour retourner le nom des colonnes du dataframe food_info 
#et convertir en liste utilisant la méthode tolist()

## 2) Créer une nouvelle liste qu'on nommera gram__columns, contenant seulement les colonnes se terminant 
##  par "(g)". Indice: la méthode endswith() retourne True si l'objet sur lequel on l'applique se termine
## par l'élément entre parenthèses. ex: total_(g).endswith("(g)") retourne True. Une boucle for est fortement conseillé pour parcourir tous les noms de colonne.

## 3) Sélectionner les colonnes de gram_columns pour le dataframe food_info et assigner le dataframe résultat 
## à la variable gram_df 

## 4) Afficher les 3 premières valeurs de ce dataframe gram_df

# %%
##--- pratique 14
#Lire le dataset 'fandango_score_comparison' dans le dataframe fandango.
#Retourner un DataFrame contenant seulement la première et la dernière ligne et assigner le résultat à la variable first_last.
#Afficher le résultat.

###--- solution

fandango = pd.read_csv('fandango_score_comparison.csv')
first = 0
last = fandango.shape[0] - 1
first_last = fandango.iloc[[first,last]]
display(first_last)
# Out:
#                                    FILM  RottenTomatoes  RottenTomatoes_User  \
# 0        Avengers: Age of Ultron (2015)              74                   86
# 145  Kumiko, The Treasure Hunter (2015)              87                   63
#
#      Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0            66              7.1   7.8             5.0                   4.5
# 145          68              6.4   6.7             3.5                   3.5
#
#      RT_norm  RT_user_norm         ...           IMDB_norm  RT_norm_round  \
# 0       3.70          4.30         ...                3.90            3.5
# 145     4.35          3.15         ...                3.35            4.5
#
#      RT_user_norm_round  Metacritic_norm_round  Metacritic_user_norm_round  \
# 0                   4.5                    3.5                         3.5
# 145                 3.0                    3.5                         3.0
#
# ...

# %%
##--- pratique 15
#Lire le fichier "fandango_score_comparison.csv" dans un dataframe qu'on nommera fandango.
#Afficher les 2 premières lignes de fandango.


fandango = pd.read_csv('fandango_score_comparison.csv')
fandango.head(2)
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
#
#    RT_norm  RT_user_norm         ...           IMDB_norm  RT_norm_round  \
# 0     3.70           4.3         ...                3.90            3.5
# 1     4.25           4.0         ...                3.55            4.5
#
#    RT_user_norm_round  Metacritic_norm_round  Metacritic_user_norm_round  \
# 0                 4.5                    3.5                         3.5
# 1                 4.0                    3.5                         4.0
#
#    IMDB_norm_round  Metacritic_user_vote_count  IMDB_user_vote_count  \
# ...
